# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Load dataset
df = pd.read_csv('Mall_Customers.csv')

# Select features
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# Elbow Method
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# Apply KMeans
kmeans = KMeans(n_clusters=5, random_state=0)
y_kmeans = kmeans.fit_predict(X)

# Visualization
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=y_kmeans)
plt.scatter(kmeans.cluster_centers_[:, 0],
            kmeans.cluster_centers_[:, 1],
            s=200, c='red')

plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Customer Segmentation")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1331/2589517214.py in <cell line: 0>()
#       4
#       5 # Load dataset
# ----> 6 df = pd.read_csv('Mall_Customers.csv')
#       7
#       8 # Select features
#
# ...

# %%
import zipfile

# ZIP file ka naam (jo tune upload kiya hai)
zip_file = "archive.zip"   # <-- apna zip ka naam yaha likh

with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall()

print("Extract ho gaya ✅")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1331/233351581.py in <cell line: 0>()
#       4 zip_file = "your_file.zip"   # <-- apna zip ka naam yaha likh
#       5
# ----> 6 with zipfile.ZipFile(zip_file, 'r') as zip_ref:
#       7     zip_ref.extractall()
#       8
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1350             while True:
#    1351                 try:
# -> 1352                     self.fp = io.open(file, filemode)
#    1353                 except OSError:
#    1354                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'your_file.zip'

# %%
import zipfile

# ZIP file ka naam (jo tune upload kiya hai)
zip_file = "archive.zip"   # <-- apna zip ka naam yaha likh

with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall()

print("Extract ho gaya ✅")
# Out:
# Extract ho gaya ✅

# %%
import os
os.listdir()
# Out:
# ['.config', 'archive.zip', 'store_customers.csv', 'sample_data']

# %%
df = pd.read_csv("store_customer.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1331/1716130699.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("store_customer.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
df = pd.read_csv("folder/store_customer.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1331/576281734.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("folder/store_customer.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
import pandas as pd

df = pd.read_csv("store_customers.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1331/2243876756.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("store_customer.csv")
#       4
#       5 df.head()
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config', 'archive.zip', 'store_customers.csv', 'sample_data']

# %%
import pandas as pd

df = pd.read_csv("store_customers.csv")

df.head()
# Out:
#    CustomerID Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0        1000      M  39.0                59.9                    58.0
# 1        1001      M  34.0                48.4                    37.0
# 2        1002      F  40.0                70.5                    26.0
# 3        1003      F  47.0                81.1                    30.0
# 4        1004      F  33.0                42.1                    58.0

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

print(X.head())
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                59.9                    58.0
# 1                48.4                    37.0
# 2                70.5                    26.0
# 3                81.1                    30.0
# 4                42.1                    58.0

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Drop rows with NaN values from X
X_cleaned = X.dropna()

wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0, n_init=10)
    kmeans.fit(X_cleaned) # Use the cleaned data
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1331/3790075499.py in <cell line: 0>()
#       6 for i in range(1, 11):
#       7     kmeans = KMeans(n_clusters=i, random_state=0)
# ----> 8     kmeans.fit(X)
#       9     wcss.append(kmeans.inertia_)
#      10
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1452             Fitted estimator.
#    1453         """
# -> 1454         X = validate_data(
#    1455             self,
#    1456             X,
#
# ...

# %%
X = X.dropna()

# %%
print(X.isnull().sum())
# Out:
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
X.fillna(X.mean(), inplace=True)

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
y_kmeans = kmeans.fit_predict(X)

# %%
print("Hello")
# Out:
# Hello

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=0)
y_kmeans = kmeans.fit_predict(X)

print("Done")
# Out:
# Done

# %%
print(type(X))
print(X.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (990, 2)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=0)
y_kmeans = kmeans.fit_predict(X)

print(y_kmeans[:10])
# Out:
# [0 0 4 1 0 2 1 4 0 0]

# %%
import matplotlib.pyplot as plt

plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=y_kmeans)

plt.scatter(kmeans.cluster_centers_[:, 0],
            kmeans.cluster_centers_[:, 1],
            s=200, c='red')

plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Customer Segmentation")
plt.show()
